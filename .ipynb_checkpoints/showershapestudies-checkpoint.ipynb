# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import uproot
import awkward as ak
import mplhep as hep
import os

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, auc
import shap
import optuna
# Out:
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-numpy/1.24.3-6c4922f4e317e74c4b82416c41722d10/lib/python3.9/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-numpy/1.24.3-6c4922f4e317e74c4b82416c41722d10/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-numpy/1.24.3-6c4922f4e317e74c4b82416c41722d10/lib/python3.9/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-numpy/1.24.3-6c4922f4e317e74c4b82416c41722d10/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
os.environ["OMP_NUM_THREADS"] = "20"
os.environ["MKL_NUM_THREADS"] = "20"

# %%
# File paths for signal and background root files: 
photon_PU0 = "/data/data.polcms/cms/debnath/CMSSW_14_0_0_pre1/src/shower_shape_studies/photons_0PU_bc_stc_hadd.root"
photon_PU200_gen = "/data/data.polcms/cms/debnath/CMSSW_14_0_0_pre1/src/shower_shape_studies/gen_filtered.h5"
photon_PU200_cl3d = "/data/data.polcms/cms/debnath/CMSSW_14_0_0_pre1/src/shower_shape_studies/cl3d_filtered.h5"
neutrino_PU200_cl3d = "/data/data.polcms/cms/debnath/CMSSW_14_0_0_pre1/src/shower_shape_studies/cl3d_filtered_neutrino.h5"
neutrino_PU200_gen = "/data/data.polcms/cms/debnath/CMSSW_14_0_0_pre1/src/shower_shape_studies/gen_filtered_neutrino.h5"

# %%
signal_file = uproot.open(photon_PU0)
signal_folder = "FloatingpointMixedbcstcrealsig4DummyHistomaxxydr015GenmatchGenclustersntuple"
#bg_folder = "l1tHGCalTriggerNtuplizer"
tree_name = "HGCalTriggerNtuple"
signal_tree_path = f"{signal_folder}/{tree_name}"

# Access the signal tree in ROOT (uproot)
signal_tree = signal_file[signal_tree_path]

# %%
def delta_r(eta1, phi1, eta2, phi2):
    delta_eta = eta1 - eta2
    delta_phi = np.abs(phi1 - phi2)
    delta_phi = np.where(delta_phi > np.pi, 2 * np.pi - delta_phi, delta_phi)  # Adjust phi to be within [-pi, pi]
    return np.sqrt(delta_eta**2 + delta_phi**2)

# %%
def filter_by_delta_r(df, delta_r_threshold=0.05):
    """Filter DataFrame to keep only the highest-energy match per event within the delta R threshold."""
    required_columns = ['cl3d_eta', 'cl3d_phi', 'genpart_exeta', 'genpart_exphi', 'cl3d_energy', 'event']

    if not all(col in df.columns for col in required_columns):
        raise ValueError(f"DataFrame must contain the following columns: {required_columns}")

    df = df.copy()  # Avoid modifying original DataFrame
    # Filter to keep only clusters with cl3d_energy > 0
    df = df[df['cl3d_ienergy'] > 0]
    # Compute delta_r
    df['delta_r'] = delta_r(df['cl3d_eta'], df['cl3d_phi'], df['genpart_exeta'], df['genpart_exphi'])
    # Filter based on delta_r threshold
    df_filtered = df[df['delta_r'] < delta_r_threshold]
    # Sort by event_id, cl3d_energy (descending), delta_r (ascending)
    df_sorted = df_filtered.sort_values(by=['event', 'cl3d_energy', 'delta_r'], ascending=[True, False, True])
    # Keep only the first occurrence per event_id
    df_best_match = df_sorted.groupby('event').first().reset_index()
    return df_best_match

# %%
# Function to load and filter the tree data (for ROOT file)
def load_and_filter_tree(tree, filter_pt = 20, eta_range=(1.6, 2.8), cl_pt_threshold=5):
    df_gen = ak.to_dataframe(tree.arrays(
        library="ak",
        filter_name=["gen_n", "gen_eta", "gen_phi", "gen_pt", 
                     "genpart_exeta", "genpart_exphi", "event"]
    ))
    df_cl3d = ak.to_dataframe(tree.arrays(
        library="ak",
        filter_name=["*cl3d*", "event"]
    ))
    df_gen_filtered = df_gen[(df_gen['gen_pt'] > filter_pt) & 
                     (abs(df_gen['gen_eta']) > eta_range[0]) & 
                     (abs(df_gen['gen_eta']) < eta_range[1])]
    df_cl3d_filtered = df_cl3d[(abs(df_cl3d['cl3d_eta']) > eta_range[0]) & 
                     (abs(df_cl3d['cl3d_eta']) < eta_range[1]) &
                     (df_cl3d['cl3d_pt'] > cl_pt_threshold)]
    merged_df = pd.merge(
        df_gen_filtered,
        df_cl3d_filtered,
        on="event",
        how="inner",  # Keep only rows where the event ID exists in both
        suffixes=('_gen', '_cl3d')  # Differentiate common column names
    )
    return merged_df

# %%
# Function to load and filter the tree data (for HDF file)
def load_and_filter_hdf(df_gen_path, df_cl3d_path):
    if df_gen_path == 'None':
        df_cl3d = pd.read_hdf(df_cl3d_path)
        return df_cl3d 
 
    else:
        df_gen = pd.read_hdf(df_gen_path)
        df_cl3d = pd.read_hdf(df_cl3d_path)
        merged_df = pd.merge(
            df_gen,
            df_cl3d,
            on="event",
            how="inner",  # Keep only rows where the event ID exists in both
            suffixes=('_gen', '_cl3d')  # Differentiate common column names
        )
        return merged_df

# %%
photonPU0_df = load_and_filter_tree(signal_tree)

# %%
photonPU200_df = load_and_filter_hdf(photon_PU200_gen, photon_PU200_cl3d)

# %%
neutrinoPU200_df = load_and_filter_hdf('None', neutrino_PU200_cl3d)

# %%
photonPU0_df_filtered = filter_by_delta_r(photonPU0_df)

# %%
photonPU200_df_filtered = filter_by_delta_r(photonPU200_df)

# %%
photonPU0_df_filtered
# Out:
#         event  gen_n   gen_eta   gen_phi     gen_pt  genpart_exphi
# 0           1      2  2.483386  2.098612  54.209084       2.098623  \
# 1           6      2  2.333653 -2.164097  22.779718      -2.164111
# 2          11      2  2.445046 -1.794452  25.749636      -1.794445
# 3          15      2 -2.753007 -2.634864  72.960312      -2.634867
# 4          17      2 -1.874361  0.769389  53.100552       0.769377
# ...       ...    ...       ...       ...        ...            ...
# 62848  199974      2  2.500853 -2.806144  27.496031      -2.806145
# 62849  199975      2 -1.770573  2.513438  85.604301       2.513438
# 62850  199979      2  2.469297  1.258688  30.444538       1.258667
# 62851  199984      2  1.694931  1.645395  61.279842       1.645386
# 62852  199991      2  2.666368  1.026271  88.189377       1.026283
#
#        genpart_exeta  cl3d_n     cl3d_id    cl3d_pt  ...  cl3d_ebm0
# 0           2.485730       2  2988204837  50.260590  ...      16383  \
# 1           2.341516       2  2988867621  21.364246  ...      16383
# 2           2.438145       2  2988872021  22.920778  ...      16383
# 3          -2.750263       2  3123589904  67.934761  ...      16383
# 4          -1.871578       2  3131877172  48.235130  ...      16383
# ...              ...     ...         ...        ...  ...        ...
# 62848       2.494332       2  2987795316  24.713163  ...      16383
# 62849      -1.761501       2  3131355987  79.840271  ...      16383
# 62850       2.460307       2  2988212530  28.673014  ...      16383
# 62851       1.696400       2  3005556018  55.947704  ...      16383
# 62852       2.687608       2  2988204065  77.077972  ...      16383
#
#        cl3d_ebm1  cl3d_hbm  cl3d_ntc67  cl3d_ntc90  cl3d_bdteg  cl3d_quality
# 0           8160   8388607    9.521496   31.513376    0.998573             1  \
# 1           4064   8388607    9.203490   27.038399    0.991326             1
# 2           4064   8388607    7.934333   26.502281    0.991326             1
# 3           2046   8388607    8.115665   29.153255    0.998785             1
# 4           4092   8388607   10.094450   29.023270    0.991326             1
# ...          ...       ...         ...         ...         ...           ...
# 62848       8064   8388607   10.906770   30.369690    0.998573             1
# 2      59.776356    464.643707  0.004327
# 3      62.515568    363.659790  0.002859
# 4      76.393753    211.907043  0.002024
# ...          ...           ...       ...
# 91676  48.723251    302.257843  0.009305
# 91677  30.000563    150.518723  0.003898
# 91678  26.311922    190.963791  0.019876
# 91679  22.853653     87.894409  0.004009
# 91680  96.590515    287.896576  0.001695
#
# [91681 rows x 60 columns]

# %%
neutrinoPU200_df_20GeV = neutrinoPU200_df[neutrinoPU200_df['cl3d_pt'] > 20]

# %%
def plot_delta_r_3d_two_dfs(df, label, eta_col='cl3d_eta', energy_col='cl3d_energy', delta_r_col='delta_r', 
                            colors=('blue', 'red'), cmap = 'plasma', figsize=(12, 8)):
    # Ensure required columns are present
    required_columns = [eta_col, delta_r_col, energy_col]
    if not all(col in df.columns for col in required_columns):
        raise ValueError(f"DataFrame must contain the following columns: {required_columns}")
    
    # Create the plot
    plt.figure(figsize=figsize)
    scatter = plt.scatter(
        df[eta_col], df[delta_r_col], c=df[energy_col], cmap=cmap, alpha=0.7, edgecolor='k', s=20
    )
    cbar = plt.colorbar(scatter, label=f"Energy [GeV]")
    # Set axis labels and title
    plt.xlabel("$\eta$ [rad]")
    plt.ylabel("$\Delta$ R [rad]")
    plt.title(f"$\Delta$ R vs $\eta$ for {label}")
    plt.tight_layout()
    filename = f"delta_r_vs_etaenergy_{label.replace(' ', '_')}.png"
    plt.savefig(filename, dpi=300)
    print(f"Saved plot as: {filename}")
    plt.show()

# %%
plot_delta_r_3d_two_dfs(photonPU0_df_filtered, 'photon PU0', colors=('blue', 'red'))
# Out:
# Saved plot as: delta_r_vs_etaenergy_photon_PU0.png

# %%
plot_delta_r_3d_two_dfs(photonPU200_df_filtered, 'photon PU200', colors=('blue', 'red'))
# Out:
# Saved plot as: delta_r_vs_etaenergy_photon_PU200.png

# %%
def plot_histograms(df_photon_no_pu, df_photon_pu200, df_neutrino_pu200, variables, num_bins=40, int_num_bins=10, cl3d_pt_range=(20, 30), figsize=(8, 4)):
    # Filter the DataFrames for cl3d_pt within the specified range
    df_photon_no_pu_filtered = df_photon_no_pu[(df_photon_no_pu['cl3d_pt'] >= cl3d_pt_range[0]) & (df_photon_no_pu['cl3d_pt'] <= cl3d_pt_range[1])]
    df_photon_pu200_filtered = df_photon_pu200[(df_photon_pu200['cl3d_pt'] >= cl3d_pt_range[0]) & (df_photon_pu200['cl3d_pt'] <= cl3d_pt_range[1])]
    df_neutrino_pu200_filtered = df_neutrino_pu200[(df_neutrino_pu200['cl3d_pt'] >= cl3d_pt_range[0]) & (df_neutrino_pu200['cl3d_pt'] <= cl3d_pt_range[1])]

    for var in variables:
        plt.figure(figsize=figsize)

        # Check if the column contains integer values
        if df_photon_no_pu_filtered[var].dtype in ['int64', 'int32']:
            # For integer columns, use integer binning
            min_value = min(
                df_photon_no_pu_filtered[var].min(),
                df_photon_pu200_filtered[var].min(),
                df_neutrino_pu200_filtered[var].min()
            )
            max_value = max(
                df_photon_no_pu_filtered[var].max(),
                df_photon_pu200_filtered[var].max(),
                df_neutrino_pu200_filtered[var].max()
            )
            
            # Create bin edges for integer columns
            bin_edges = np.arange(min_value - 0.5, max_value + 1.5, 1)
        else:
            # For non-integer columns, use a normal binning strategy
            min_value = min(
                df_photon_no_pu_filtered[var].min(),
                df_photon_pu200_filtered[var].min(),
                df_neutrino_pu200_filtered[var].min()
            )
            max_value = max(
                df_photon_no_pu_filtered[var].max(),
                df_photon_pu200_filtered[var].max(),
                df_neutrino_pu200_filtered[var].max()
            )
            bin_width = (max_value - min_value) / num_bins
            bin_edges = np.arange(min_value - bin_width / 2, max_value + bin_width / 2, bin_width)

        # Plot the histograms for all three datasets
        plt.hist(df_photon_no_pu_filtered[var], bins=bin_edges, color='g', histtype='step', linewidth=1.5, label='Photon (0 PU)', density = True)
        plt.hist(df_photon_pu200_filtered[var], bins=bin_edges, color='b', histtype='step', linewidth=1.5, label='Photon (200 PU)', density = True)
        plt.hist(df_neutrino_pu200_filtered[var], bins=bin_edges, color='r', histtype='step', linewidth=1.5, label='Neutrino (200 PU)', density = True)

        # Set the plot title, labels, and legend
        plt.title(f"{var} Histogram (cl3d_pt between {cl3d_pt_range[0]} and {cl3d_pt_range[1]} GeV)")
        plt.xlabel(var)
        plt.ylabel('Normalized Frequency')
        plt.legend()

        # Adjust layout to prevent clipping
        plt.tight_layout()

        # Save the plot as a PNG file
        filename = f"{var}_histogram_cl3d_pt_{cl3d_pt_range[0]}_{cl3d_pt_range[1]}_20GeV.png"
        plt.savefig(filename, dpi=300)
        print(f"Saved: {filename}")

        # Show the plot
        plt.show()

        # Close the plot to free memory
        plt.close()

# %%
variables = ['cl3d_pt', 'cl3d_energy', 'cl3d_eta', 'cl3d_emax1layers', 'cl3d_emax3layers',
       'cl3d_phi', 'cl3d_showerlength','cl3d_coreshowerlength', 'cl3d_firstlayer', 'cl3d_maxlayer',
       'cl3d_seetot', 'cl3d_seemax', 'cl3d_spptot', 'cl3d_sppmax', 'cl3d_szz',
       'cl3d_srrtot', 'cl3d_srrmax', 'cl3d_srrmean', 'cl3d_varrr',
       'cl3d_varzz', 'cl3d_varee', 'cl3d_varpp', 'cl3d_emaxe', 'cl3d_hoe',
       'cl3d_meanz', 'cl3d_layer10', 'cl3d_layer50', 'cl3d_layer90',
       'cl3d_first1layers', 'cl3d_first3layers', 'cl3d_first5layers',
       'cl3d_firstHcal1layers', 'cl3d_firstHcal3layers',
       'cl3d_firstHcal5layers', 'cl3d_last1layers', 'cl3d_last3layers',
       'cl3d_last5layers']

# %%
plot_histograms(photonPU0_df_filtered, photonPU200_df_filtered, neutrinoPU200_df_20GeV, variables, cl3d_pt_range=(20, 30))
# Out:
# Saved: cl3d_pt_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_energy_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_eta_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_emax1layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_emax3layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_phi_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_showerlength_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_coreshowerlength_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_firstlayer_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_maxlayer_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_seetot_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_seemax_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_spptot_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_sppmax_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_szz_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_srrtot_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_srrmax_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_srrmean_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_varrr_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_varzz_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_varee_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_varpp_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_emaxe_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_hoe_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_meanz_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_layer10_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_layer50_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_layer90_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_first1layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_first3layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_first5layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_firstHcal1layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_firstHcal3layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_firstHcal5layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_last1layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_last3layers_histogram_cl3d_pt_20_30_20GeV.png
# Saved: cl3d_last5layers_histogram_cl3d_pt_20_30_20GeV.png

# %%
# Get the common columns between signal and background DataFrames
common_columns = photonPU200_df_filtered.columns.intersection(neutrinoPU200_df_20GeV.columns)

# Keep only the common columns in both DataFrames
neutrinoPU200_df_final = neutrinoPU200_df_20GeV[common_columns]
photonPU200_df_final = photonPU200_df_filtered[common_columns]
photonPU0_df_final = photonPU0_df_filtered[common_columns]

# %%
# Combine the data
neutrinoPU200_df_final['label'] = 0  # Label for neutrino background
photonPU200_df_final['label'] = 1    # Label for photon signal
photonPU0_df_final['label'] = 1      # Photon signal for PU=0

# Concatenate all datasets
df_combined = pd.concat([neutrinoPU200_df_final, photonPU200_df_final, photonPU0_df_final], ignore_index=True)
# Out:
# /tmp/ipykernel_38291/1225579273.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   photonPU200_df_final['label'] = 1    # Label for photon signal
# /tmp/ipykernel_38291/1225579273.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   photonPU0_df_final['label'] = 1      # Photon signal for PU=0

# %%
# Define pT bins and process data
pt_bins = [20, 30, 40, 50]  # Example bins
df_combined['pt_bin'] = pd.cut(df_combined['cl3d_pt'], bins=pt_bins, labels=False)

columns_for_training = [
    'cl3d_showerlength', 'cl3d_coreshowerlength', 'cl3d_firstlayer', 'cl3d_maxlayer',
    'cl3d_seetot', 'cl3d_seemax', 'cl3d_spptot', 'cl3d_sppmax', 'cl3d_szz',
    'cl3d_srrtot', 'cl3d_srrmax', 'cl3d_srrmean', 'cl3d_varrr', 'cl3d_varzz',
    'cl3d_varee', 'cl3d_varpp', 'cl3d_emaxe', 'cl3d_meanz', 
    'cl3d_layer10', 'cl3d_layer50', 'cl3d_layer90', 'cl3d_first1layers',
    'cl3d_first3layers', 'cl3d_first5layers', 'cl3d_firstHcal1layers',
    'cl3d_firstHcal3layers', 'cl3d_firstHcal5layers', 'cl3d_last1layers',
    'cl3d_last3layers', 'cl3d_last5layers', 'cl3d_emax1layers', 'cl3d_emax3layers'
]

# %%
filtered_data = df_combined[columns_for_training + ['label', 'pt_bin']]
feature_importance_by_bin = {}
shap_values_by_bin = {}
mean_shap_values = {}

# %%
def objective(trial, X_train, y_train, X_test, y_test):
    """Optuna objective function to optimize XGBoost hyperparameters while keeping memory usage optimized."""
    params = {
        "objective": "binary:logistic",
        "eval_metric": "auc",
        "use_label_encoder": False,
        "n_estimators": 100,  # Fixed to avoid excessive memory usage
        "max_depth": trial.suggest_int("max_depth", 1, 4),  # Reduce max depth to keep memory low
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.05, log=True),  
        "colsample_bytree": 0.8,  # Fixed to a reasonable value
        "subsample": 0.8,  # Fixed to avoid randomness
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1, 10),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 5),
    }

    model = xgb.XGBClassifier(**params)
    model.fit(X_train, y_train)
    
    # Evaluate AUC
    y_pred = model.predict_proba(X_test)[:, 1]
    return roc_auc_score(y_test, y_pred)

# %%
for pt_bin in range(len(pt_bins) - 1):  
    print(f"Optimizing for pT bin: {pt_bins[pt_bin]} - {pt_bins[pt_bin + 1]}")

    bin_data = filtered_data[filtered_data['pt_bin'] == pt_bin]
    X = bin_data[columns_for_training]
    y = bin_data['label']

    # Check class balance
    class_counts = y.value_counts()
    if len(class_counts) < 2:  
        print(f"Skipping bin {pt_bins[pt_bin]} - {pt_bins[pt_bin + 1]} due to insufficient class diversity.")
        continue

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Optuna hyperparameter tuning
    study = optuna.create_study(direction="maximize")
    study.optimize(lambda trial: objective(trial, X_train, y_train, X_test, y_test), n_trials=100, n_jobs=1)  # Reduce trials for efficiency

    print(f"Best parameters for pT bin {pt_bins[pt_bin]} - {pt_bins[pt_bin + 1]}: {study.best_params}")

    # Train final model with best parameters
    best_params = study.best_params
    best_params.update({"n_jobs": 20})  
    best_model = xgb.XGBClassifier(**best_params)
    best_model.fit(X_train, y_train)

    # SHAP analysis
    explainer = shap.Explainer(best_model, X_train)
    shap_values = explainer(X_test)
    shap_values_by_bin[pt_bin] = shap_values

    # Compute Mean Absolute SHAP Value for each feature
    mean_abs_shap = np.abs(shap_values.values).mean(axis=0)

    # Store feature importance
    for feature, shap_mean in zip(columns_for_training, mean_abs_shap):
        if feature not in mean_shap_values:
            mean_shap_values[feature] = []
        mean_shap_values[feature].append(shap_mean)

    # Generate SHAP summary plot
    plt.figure()
    shap.summary_plot(shap_values, X_test, show=False)
    plt.title(f"SHAP Summary for pT Bin: {pt_bins[pt_bin]} - {pt_bins[pt_bin + 1]}")
    filename = f"{pt_bins[pt_bin]}_shap_summary_20GeV.png"
    plt.savefig(filename, dpi=300)
    print(f"Saved: {filename}")
    plt.show()

    # Generate SHAP dependence plots for the top features
    for feature in columns_for_training[:3]:  
        plt.figure()
        shap.dependence_plot(feature, shap_values.values, X_test, show=False)
        filename = f"{pt_bins[pt_bin]}_shap_dependence_{feature}.png"
        plt.savefig(filename, dpi=300)
        print(f"Saved: {filename}")
        plt.show()
# Out:
# [I 2025-02-04 14:44:36,231] A new study created in memory with name: no-name-e68a01d9-406a-4cf7-a7bc-72e94330baa6
# Optimizing for pT bin: 20 - 30
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:37,527] Trial 0 finished with value: 0.9974368997996453 and parameters: {'max_depth': 4, 'learning_rate': 0.022604455793149028, 'gamma': 0.7557536578714935, 'reg_lambda': 5.2652351227824035, 'reg_alpha': 0.3714871423027477}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:38,274] Trial 1 finished with value: 0.9958779909264677 and parameters: {'max_depth': 3, 'learning_rate': 0.012050415851869134, 'gamma': 3.9161872978134764, 'reg_lambda': 3.42228613437212, 'reg_alpha': 2.345164739279864}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:38,697] Trial 2 finished with value: 0.9902196032824386 and parameters: {'max_depth': 2, 'learning_rate': 0.0017351399482694583, 'gamma': 2.86300718143008, 'reg_lambda': 1.5400540631611903, 'reg_alpha': 3.919914620039067}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:39,132] Trial 3 finished with value: 0.990545352309452 and parameters: {'max_depth': 2, 'learning_rate': 0.0027284763038439856, 'gamma': 1.8483170664407278, 'reg_lambda': 6.325019113150655, 'reg_alpha': 1.0682143188425637}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:39,415] Trial 4 finished with value: 0.9723526702438801 and parameters: {'max_depth': 1, 'learning_rate': 0.0030885346831071112, 'gamma': 3.380994365994318, 'reg_lambda': 5.643934872562291, 'reg_alpha': 4.214401958177354}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:39,839] Trial 5 finished with value: 0.9906971727732614 and parameters: {'max_depth': 2, 'learning_rate': 0.0032937958677577823, 'gamma': 4.005400610400172, 'reg_lambda': 2.3317251080662285, 'reg_alpha': 1.7402250027144954}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:40,586] Trial 6 finished with value: 0.9953242137423332 and parameters: {'max_depth': 3, 'learning_rate': 0.007450988018530753, 'gamma': 0.03449179531458402, 'reg_lambda': 4.305185312307945, 'reg_alpha': 4.457000942290671}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:41,197] Trial 7 finished with value: 0.9952467010570434 and parameters: {'max_depth': 3, 'learning_rate': 0.004674395329054828, 'gamma': 3.4157228791407803, 'reg_lambda': 2.6591739344228946, 'reg_alpha': 1.1659502914588744}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44:41,790] Trial 8 finished with value: 0.9956935072810875 and parameters: {'max_depth': 3, 'learning_rate': 0.010694536565764386, 'gamma': 4.4214706691935355, 'reg_lambda': 8.340808443872788, 'reg_alpha': 3.5837385987352928}. Best is trial 0 with value: 0.9974368997996453.
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:44
# /cvmfs/cms.cern.ch/slc7_amd64_gcc12/external/py3-xgboost/1.7.5-788de805c13027be61faccd00ffc7e59/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2025-02-04 14:51:25,532] Trial 99 finished with value: 0.9986227121129292 and parameters: {'max_depth': 4, 'learning_rate': 0.04384244472993725, 'gamma': 0.7892875037387644, 'reg_lambda': 5.852497973510555, 'reg_alpha': 0.9952996670739876}. Best is trial 98 with value: 0.9986280093740333.
# Best parameters for pT bin 40 - 50: {'max_depth': 4, 'learning_rate': 0.0432259563732082, 'gamma': 0.8472050638315183, 'reg_lambda': 5.8906885716506805, 'reg_alpha': 0.6992268654143408}
# Saved: 40_shap_summary_20GeV.png
# Saved: 40_shap_dependence_cl3d_showerlength.png
# Saved: 40_shap_dependence_cl3d_coreshowerlength.png
# Saved: 40_shap_dependence_cl3d_firstlayer.png

# %%
max_bits = 16
def truncate_mantissa(arr, bits):
    if bits < 0 or bits > max_bits:
        raise ValueError("Bits must be between 0 and "+str(max_bits)+" for a 32-bit float.")

    # Create a mask to truncate the mantissa
    mask = np.array([(0xFFFFFFFF >> (max_bits - bits)) << (max_bits - bits)], dtype=np.uint32)
    print(f"Mask: {mask[0]:32b}")
    # Convert the array to 32-bit floats
    arr = arr.astype(np.float32)

    # Get the bit representation of the floats
    int_view = arr.view(np.uint32)
    int_view = int_view & mask

    # Convert back to float
    return int_view.view(np.float32)

# Example usage
arr = np.array([1.23456789, 2.3456789, 3.456789, 5.8], dtype=np.float32)
truncated_arr = truncate_mantissa(arr, 4)

print(f"Input array: {arr}")
print(f"Truncated array: {truncated_arr}")
# Out:
# Mask: 11111111111111111111000000000000
# Input array: [1.2345679 2.3456788 3.456789  5.8      ]
# Truncated array: [1.234375  2.3447266 3.4560547 5.798828 ]

# %%
def quantize_feature(series, n_mantissa_bits, value_range=None):
    """
    Quantizes a pandas Series by truncating the precision to n_mantissa_bits.
    
    Parameters:
      series: pandas Series of floating point numbers.
      n_mantissa_bits: Number of bits to keep in the fractional part.
      value_range: Tuple (min, max) of values to consider. If None, uses the Series' min and max.
    
    Returns:
      Quantized Series.
    """
    # Determine the range if not provided.
    if value_range is None:
        min_val, max_val = series.min(), series.max()
    else:
        min_val, max_val = value_range

    # Decide on the number of quantization levels.
    # For example, if we want n bits of resolution then:
    n_levels = 2 ** n_mantissa_bits

    # It is often useful to normalize the data to [0, 1] first
    normalized = (series - min_val) / (max_val - min_val)
    
    # Quantize: multiply by number of levels, floor it to truncate,
    # then divide back by number of levels and rescale.
    quantized = np.floor(normalized * n_levels) / n_levels
    quantized = quantized * (max_val - min_val) + min_val
    
    return quantized

# %%
# Suppose you already determined your most important features.
# For example, let's assume these are stored in:
most_important_features = list(mean_shap_values.keys())[:10]

# Choose the number of bits you want to keep in the fractional part.
# (For example, 10 bits.)
n_mantissa_bits = 8

# Apply quantization to both your training and testing sets.
for feature in most_important_features:
    # Optionally, you might want to use a pre-determined range for each feature,
    # or simply let the function compute it from the data.
    X_train[feature] = quantize_feature(X_train[feature], n_mantissa_bits)
    X_test[feature] = quantize_feature(X_test[feature], n_mantissa_bits)

# You can now retrain your model (or re-run inference) with the quantized values.
# For example:
best_model = xgb.XGBClassifier(**best_params)
best_model.fit(X_train, y_train)

# And if desired, run your SHAP analysis again with the quantized inputs:
explainer = shap.Explainer(best_model, X_train)
shap_values = explainer(X_test)
shap.summary_plot(shap_values, X_test)
plt.show()

# %%
print(list(mean_shap_values.keys())[:15])
# Out:
# ['cl3d_showerlength', 'cl3d_coreshowerlength', 'cl3d_firstlayer', 'cl3d_maxlayer', 'cl3d_seetot', 'cl3d_seemax', 'cl3d_spptot', 'cl3d_sppmax', 'cl3d_szz', 'cl3d_srrtot', 'cl3d_srrmax', 'cl3d_srrmean', 'cl3d_varrr', 'cl3d_varzz', 'cl3d_varee']
